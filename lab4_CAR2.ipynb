# %%
# !pip install pandas
import pandas as pd

# %%
data=pd.read_csv(r'csv_files\marketing_customer_analysis.csv')
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#Show the dataframe shape

# %%
data.shape
# Out:
# (10910, 26)

# %%
#Standardize header names

# %%
datacols=[data.columns[i].lower().replace(" ", "_") for i in range(len(data.columns))]
data.columns=datacols
data
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
#Which columns are numerical?
#Which columns are categorical?

# %%
numcols=data.select_dtypes("number").columns.tolist()
numcols
# Out:
# ['unnamed:_0',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'total_claim_amount']

# %%
catcols=data.select_dtypes("object").columns.tolist()
catcols
# Out:
# ['customer',
#  'state',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'location_code',
#  'marital_status',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
data.drop(['unnamed:_0','education','number_of_open_complaints'], axis='columns', inplace=True)

# %%
display(data)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       effective_to_date employmentstatus gender  income location_code  ...  \
# ...

# %%
data1=data.copy()
data1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       effective_to_date employmentstatus gender  income location_code  ...  \
# ...

# %%
#######added--checking for duplicates

# %%
data1.duplicated(keep='first')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10905    False
# 10906    False
# 10907    False
# 10908    False
# 10909    False
# Length: 10910, dtype: bool

# %%
data1.drop_duplicates(inplace=True)
data1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       effective_to_date employmentstatus gender  income location_code  ...  \
# ...

# %%
#Check and deal with NaN values

# %%
data1.isna()
# Out:
#        customer  state  customer_lifetime_value  response  coverage  \
# 0         False  False                    False     False     False
# 1         False  False                    False     False     False
# 2         False  False                    False     False     False
# 3         False  False                    False     False     False
# 4         False  False                    False     False     False
# ...         ...    ...                      ...       ...       ...
# 10905     False  False                    False     False     False
# 10906     False  False                    False     False     False
# 10907     False  False                    False     False     False
# 10908     False  False                    False     False     False
# 10909     False   True                    False      True     False
#
#        effective_to_date  employmentstatus  gender  income  location_code  \
# 0                  False             False   False   False          False
# ...

# %%
pd.isna(data1).sum()
# Out:
# customer                            0
# state                             614
# customer_lifetime_value             0
# response                          614
# coverage                            0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           623
# months_since_policy_inception       0
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     608
# vehicle_size                      608
# vehicle_type                     5465
# dtype: int64

# %%
data1[data1['vehicle_type'].isna()]
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 4      QA50777      Oregon              9025.067525       No   Premium
# 6      IW72280  California              5035.035257       No     Basic
# 7      IH64929  California              4956.247235       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10898  SO95845  California              5807.659307       No     Basic
# 10900  VN73653      Oregon              6423.739052       No     Basic
# 10901  RY92254  Washington              4547.892543       No   Premium
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       effective_to_date employmentstatus gender  income location_code  ...  \
# ...

# %%
data2=data1.copy()

# %%
data2.drop(['vehicle_type'], axis='columns', inplace=True)

# %%
pd.isna(data2).sum()
# Out:
# customer                           0
# state                            614
# customer_lifetime_value            0
# response                         614
# coverage                           0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim          623
# months_since_policy_inception      0
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                    608
# vehicle_size                     608
# dtype: int64

# %%
data2['state'].value_counts()
#drop
# Out:
# California    3548
# Oregon        2897
# Arizona       1934
# Nevada         992
# Washington     888
# Name: state, dtype: int64

# %%
data2['state'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10905    False
# 10906    False
# 10907    False
# 10908    False
# 10909     True
# Name: state, Length: 10873, dtype: bool

# %%
data2['state'].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)

# %%
data2['response'].value_counts()
#drop
# Out:
# No     8795
# Yes    1464
# Name: response, dtype: int64

# %%
data2['response'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
####state and response have the same numbers of NANs. I will try to drop

# %%
data2['months_since_last_claim'].value_counts()
###drop the NANs here. if fill nans with zero I'll have a discrepant\unreal value in the sum of those clientes whose claim was made before completing one month
# Out:
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     377
# 4.0     372
# 2.0     365
# 5.0     354
# 0.0     353
# 10.0    345
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    306
# 17.0    298
# 14.0    297
# 19.0    275
# 9.0     275
# 23.0    273
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    245
# 24.0    236
# 29.0    233
# 28.0    225
# 31.0    219
# 26.0    211
# 27.0    207
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    156
# 32.0    155
# Name: months_since_last_claim, dtype: int64

# %%
data2['vehicle_class'].value_counts()
#drop
# Out:
# Four-Door Car    5200
# Two-Door Car     2112
# SUV              2009
# Sports Car        548
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle_class, dtype: int64

# %%
data2['vehicle_size'].value_counts()
#drop
# Out:
# Medsize    7233
# Small      1962
# Large      1070
# Name: vehicle_size, dtype: int64

# %%
data3=data2.copy()

# %%
data3.dropna(subset=['vehicle_size', 'vehicle_class', 'state', 'response'])
data3
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       effective_to_date employmentstatus gender  income location_code  ...  \
# ...

# %%
pd.isna(data3).sum()
# Out:
# customer                           0
# state                            614
# customer_lifetime_value            0
# response                         614
# coverage                           0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim          623
# months_since_policy_inception      0
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                    608
# vehicle_size                     608
# dtype: int64

# %%
data3 = data3.dropna(subset=data3.columns.values)
data3
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#       effective_to_date employmentstatus gender  income location_code  ...  \
# ...

# %%
pd.isna(data3).sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %%
droped=10873-9134
droped
# Out:
# 1739

# %% [raw]
# Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
import datetime as dt
from datetime import date

today = date.today()
today
# Out:
# datetime.date(2023, 5, 17)

# %%
data4=data3.copy()

# %%
data4['months_since_last_claim'] = pd.to_datetime(data4['months_since_last_claim'], errors='coerce')
data4['months_since_last_claim']
# Out:
# 0       1970-01-01 00:00:00.000000007
# 1       1970-01-01 00:00:00.000000003
# 2       1970-01-01 00:00:00.000000034
# 3       1970-01-01 00:00:00.000000010
# 6       1970-01-01 00:00:00.000000008
#                      ...
# 10903   1970-01-01 00:00:00.000000030
# 10904   1970-01-01 00:00:00.000000014
# 10906   1970-01-01 00:00:00.000000007
# 10907   1970-01-01 00:00:00.000000011
# 10908   1970-01-01 00:00:00.000000000
# Name: months_since_last_claim, Length: 9134, dtype: datetime64[ns]

# %%
data4['months_since_policy_inception'] = pd.to_datetime(data4['months_since_policy_inception'], errors='coerce')
data4['months_since_policy_inception']
# Out:
# 0       1970-01-01 00:00:00.000000052
# 1       1970-01-01 00:00:00.000000026
# 2       1970-01-01 00:00:00.000000031
# 3       1970-01-01 00:00:00.000000003
# 6       1970-01-01 00:00:00.000000099
#                      ...
# 10903   1970-01-01 00:00:00.000000082
# 10904   1970-01-01 00:00:00.000000032
# 10906   1970-01-01 00:00:00.000000068
# 10907   1970-01-01 00:00:00.000000063
# 10908   1970-01-01 00:00:00.000000027
# Name: months_since_policy_inception, Length: 9134, dtype: datetime64[ns]

# %% [raw]
# data['state'] = data['state'].apply(lambda x: 'CA' if x in ['California', 'Cali'] else x) # apply on a series

# %%
data4[months]=dt.month('months_since_last_claim','months_since_policy_inception')
data4
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 data4[months]=dt.month('months_since_last_claim','months_since_policy_inception')
#       2 data4
#
# AttributeError: module 'datetime' has no attribute 'month'

# %%
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1066    False
# 1067    False
# 1068    False
# 1069    False
# 1070    False
# Name: income, Length: 1071, dtype: bool

# %%
# Out:
# customer                     0
# st                           0
# gender                     117
# customer_lifetime_value      3
# income                       0
# monthly_premium_auto         0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
# Out:
#     customer          st gender  customer_lifetime_value   income  \
# 0    RB50392  Washington    NaN                      NaN      0.0
# 11   VQ65197  California    NaN             8.197197e+09      0.0
# 12   DP39365  California    NaN             8.798797e+09  77026.0
# 13   SJ95423     Arizona    NaN             8.819019e+09  99845.0
# 14   IL66569  California    NaN             5.384432e+09  83689.0
# ..       ...         ...    ...                      ...      ...
# 134  BU44523          AZ    NaN             8.026380e+09      0.0
# 135  MS41162          AZ    NaN             4.022964e+09      0.0
# 136  PU25891      Oregon    NaN             9.618311e+09  80536.0
# 138  SX26335      Oregon    NaN             9.552927e+09  97732.0
# 449  LN31673  Washington    NaN             1.131809e+10  38923.0
#
#      monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                  1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
# Out:
# nan

# %%
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 3208  TM65736      Oregon      M                Master
# 3209  VJ51327        Cali      F  High School or Below
# 3210  GS98873     Arizona      F              Bachelor
# 3211  CW49887  California      F                Master
# 3212  MY31220  California      F               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Out:
# Index(['income', 'monthly_premium_auto', 'total_claim_amount'], dtype='object')

# %%
# Out:
# ['number_of_open_complaints', 'policy_type', 'vehicle_class', 'customer_lifetime_value', 'customer', 'education', 'st', 'gender']
